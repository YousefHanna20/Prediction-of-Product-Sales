# %% [markdown]
# <a href="https://colab.research.google.com/github/YousefHanna20/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales

# %% [markdown]
# - Author: Yousef Hanna

# %% [markdown]
# ## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Feature Inspection
